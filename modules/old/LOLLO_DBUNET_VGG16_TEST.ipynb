# %%
from google.colab import drive
drive.mount('/content/drive')

root_path = '/content/drive/MyDrive/CVDL'
dumps_path =  f"{root_path}/dumps/"
dataset  = f"{root_path}/dataset/"

# !cp "$root_path/modules/lib.py" .
# !cp "$root_path/modules/plots.py" .
# !cp "$root_path/modules/metrics.py" .
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Imports

# %%
import cv2
import pickle
import matplotlib.pyplot as plt
import numpy as np
import cv2 as cv
import os
import tensorflow as tf
import importlib
from datetime import datetime

from keras.initializers import glorot_uniform

import lib
import plots
import metrics

tf.keras.backend.clear_session()

# %% [markdown]
# ## Parameters

# %%
# Deafault Res: 606x468 (ar 101 : 78)

# Tested Res's:
# 224x160 (ar 7 : 5)
# 384x288
# 576x432
# 512x384
input_res = (384, 288)

seed = 42

params = {
          'x':input_res[0],                                
          'y':input_res[1],                                
          'batch_size': 8,                        
          'n_channels_mask': 1,                            
          'n_channels': 1,                        
          'shuffle': True,              
          'learningRate': 1e-3,                       
          'nEpoches': 100,                        
          }

ratio_test = 0.85
ratio_val  = 0.8

lib.create_dump([params, seed], dumps_path + "params_du")

type_ds  = ['Images','Masks']
modality = ['train','validation','test']

# get path Img and Mask
path_img  = os.path.join(dataset, type_ds[0])
path_msk  = os.path.join(dataset, type_ds[1])
path_     = [path_img, path_msk]

# get length imgs and proof that is equal with masks
length_imgs  = len(os.listdir(os.path.join(dataset,type_ds[0] + "/"))) 
length_masks = len(os.listdir(os.path.join(dataset,type_ds[1] + "/")))
params['length_data'] = length_imgs,

# get name of file imgs
imgs_list_path = os.listdir(path_img)

# %% [markdown]
# ## Data loading

# %%
# LOAD & SPLIT DATA ============================================================
'''
mode = 1  # mode = 0: Random Split
          # mode = 1: Split for Patients
          
dataset_list = lib.get_dataset_list(
                                mode, 
                                path_, 
                                imgs_list_path, 
                                params, 
                                ratio_test, 
                                ratio_val, 
                                seed, 
                                modality)

# Dumping splitted data
lib.create_dump(dataset_list, f"{dumps_path}data_rt{ratio_test}_rv{ratio_val}_{input_res[0]}x{input_res[1]}")

'''
# Out:
# '\nmode = 1  #\xa0mode = 0: Random Split\n          #\xa0mode = 1: Split for Patients\n          \ndataset_list = lib.get_dataset_list(\n                                mode, \n                                path_, \n                                imgs_list_path, \n                                params, \n                                ratio_test, \n                                ratio_val, \n                                seed, \n                                modality)\n\n# Dumping splitted data\nlib.create_dump(dataset_list, f"{dumps_path}data_rt{ratio_test}_rv{ratio_val}_{input_res[0]}x{input_res[1]}")\n\n'

# %% [markdown]
# ##Loading Data from Pickle

# %%
dataset_list = pickle.load(open( f"{dumps_path}data_rt{ratio_test}_rv{ratio_val}_{input_res[0]}x{input_res[1]}", "rb" ))

# %% [markdown]
# ##Data Augmentation

# %%
# DATA AUGMENTATION ============================================================
train_generator, val_generator = lib.data_augmentation(seed, dataset_list, params)

params["length_training"]   = len(dataset_list[0]['train'])
params['length_validation'] = len(dataset_list[0]['validation'])

augmented_batch_plot = plots.plot_augmented_batch(train_generator)
plt.show()

# %%
print(params["length_training"])
print(params['length_validation'])
print(len(dataset_list[0]['test']))
# Out:
# 164
# 38
# 44

# %% [markdown]
# # Models

# %% [markdown]
# ## load models

# %%
from tensorflow import keras
'''
loss      = metrics.bce_dice_loss
recall    = tf.keras.metrics.Recall()
precision = tf.keras.metrics.Precision()
metric    = [metrics.dice, metrics.iou, recall, precision]

c_objects = {
    "bce_dice_loss": metrics.bce_dice_loss,
    "dice": metrics.dice,
    "iou": metrics.iou,
    "precision": tf.keras.metrics.Precision(),
    "recall": tf.keras.metrics.Recall(),
}

path_trained_models = '/content/drive/MyDrive/CVDL/trained_models/'

path_unet = 'unet'
path_lunet = 'lunet'
path_dblunet = 'dblunet'

model_unet = keras.models.load_model(f'{path_trained_models}/{path_unet}/model.h5', custom_objects=c_objects)
model_lunet = keras.models.load_model(f'{path_trained_models}/{path_lunet}/model.h5', custom_objects=c_objects)
model_dblunet = keras.models.load_model(f'{path_trained_models}/{path_dblunet}/model.h5', custom_objects=c_objects)

model_unet.compile(loss=metrics.bce_dice_loss, optimizer='adam', metrics=metric)
model_lunet.compile(loss=metrics.bce_dice_loss, optimizer='adam', metrics=metric)
model_dblunet.compile(loss=metrics.bce_dice_loss, optimizer='adam', metrics=metric)

history_unet = pickle.load(open( f"{path_trained_models}/{path_unet}/train_history", "rb" ))
history_lunet = pickle.load(open( f"{path_trained_models}/{path_lunet}/train_history", "rb" ))
history_dblunet = pickle.load(open( f"{path_trained_models}/{path_dblunet}/train_history", "rb" ))
'''

# %% [markdown]
# ## train models

# %%
params['learningRate'] = 1e-3
params['nEpoches'] = 100

models_name = ['unet', 'lightweight_unet', 'dbunet_BN', 'dbunet_BN_vgg16']
arch_name = models_name[3]


# !cp "$root_path/modules/models/{arch_name}.py" .
arch = importlib.import_module(arch_name)

input_size = (input_res[1], input_res[0], 1)

initializer = tf.keras.initializers.GlorotUniform()
model = arch.build_model(initializer, input_size)

model_weights = f"{root_path}/dataset/results/models/{arch_name}_Glorot_e{params['nEpoches']}_lr{params['learningRate']}"
#model_weights = "/content/"
log_path = f"{model_weights}/logs/fit/" + datetime.now().strftime("%Y%m%d-%H%M%S")
# !rm -rf $log_path

#model.summary()

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 288, 384, 1) 0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 288, 384, 3)  0           input_1[0][0]
#                                                                  input_1[0][0]
#                                                                  input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 288, 384, 64) 1792        concatenate[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 288, 384, 64) 36928       block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 144, 192, 64) 0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 144, 192, 128 73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, 144, 192, 128 147584      block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 72, 96, 128)  0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, 72, 96, 256)  295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, 72, 96, 256)  590080      block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, 72, 96, 256)  590080      block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv4 (Conv2D)           (None, 72, 96, 256)  590080      block3_conv3[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 36, 48, 256)  0           block3_conv4[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, 36, 48, 512)  1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, 36, 48, 512)  2359808     block4_conv1[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, 36, 48, 512)  2359808     block4_conv2[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 1, 1, 512)    0           block4_conv3[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 1, 1, 64)     32832       average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 1, 1, 64)     256         conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 36, 48, 64)   32768       block4_conv3[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 36, 48, 64)   294912      block4_conv3[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 36, 48, 64)   294912      block4_conv3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 36, 48, 64)   294912      block4_conv3[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 1, 1, 64)     0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 36, 48, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 36, 48, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 36, 48, 64)   256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 36, 48, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 36, 48, 64)   0           activation[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 36, 48, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 36, 48, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 36, 48, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 36, 48, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 36, 48, 320)  0           up_sampling2d[0][0]
#                                                                  activation_1[0][0]
#                                                                  activation_2[0][0]
#                                                                  activation_3[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 36, 48, 64)   20480       concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 36, 48, 64)   256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 36, 48, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 72, 96, 64)   0           activation_5[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 72, 96, 320)  0           up_sampling2d_1[0][0]
#                                                                  block3_conv3[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 72, 96, 128)  368768      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 72, 96, 128)  512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 72, 96, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 72, 96, 128)  147584      activation_6[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 72, 96, 128)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 128)          0           activation_7[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 1, 128)    0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1, 1, 16)     2048        reshape[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1, 1, 128)    2048        dense[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 72, 96, 128)  0           activation_7[0][0]
#                                                                  dense_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 144, 192, 128 0           multiply[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 144, 192, 256 0           up_sampling2d_2[0][0]
#                                                                  block2_conv2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 144, 192, 64) 147520      concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 144, 192, 64) 256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 144, 192, 64) 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 144, 192, 64) 36928       activation_8[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 144, 192, 64) 0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 64)           0           activation_9[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 1, 64)     0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1, 1, 8)      512         reshape_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1, 1, 64)     512         dense_2[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 144, 192, 64) 0           activation_9[0][0]
#                                                                  dense_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 288, 384, 64) 0           multiply_1[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 288, 384, 128 0           up_sampling2d_3[0][0]
#                                                                  block1_conv2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 288, 384, 32) 36896       concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 288, 384, 32) 128         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 288, 384, 32) 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 288, 384, 32) 9248        activation_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 288, 384, 32) 0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 32)           0           activation_11[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1, 1, 32)     0           global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1, 1, 4)      128         reshape_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1, 1, 32)     128         dense_4[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 288, 384, 32) 0           activation_11[0][0]
#                                                                  dense_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 288, 384, 2)  578         multiply_2[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 288, 384, 2)  0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 288, 384, 1)  3           activation_12[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 288, 384, 1)  0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply (TFOpLambda)   (None, 288, 384, 1)  0           input_1[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 288, 384, 32) 320         tf.math.multiply[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 288, 384, 32) 128         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 288, 384, 32) 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 288, 384, 32) 9248        activation_14[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 288, 384, 32) 0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 32)           0           activation_15[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 1, 1, 32)     0           global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 1, 1, 4)      128         reshape_3[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1, 1, 32)     128         dense_6[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 288, 384, 32) 0           activation_15[0][0]
#                                                                  dense_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 144, 192, 32) 0           multiply_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 144, 192, 64) 18496       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 144, 192, 64) 256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 144, 192, 64) 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 144, 192, 64) 36928       activation_16[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 144, 192, 64) 0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 64)           0           activation_17[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 1, 1, 64)     0           global_average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 1, 1, 8)      512         reshape_4[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 1, 1, 64)     512         dense_8[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 144, 192, 64) 0           activation_17[0][0]
#                                                                  dense_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 72, 96, 64)   0           multiply_4[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 72, 96, 128)  73856       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 72, 96, 128)  512         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 72, 96, 128)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 72, 96, 128)  147584      activation_18[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 72, 96, 128)  0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_5 (Glo (None, 128)          0           activation_19[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 1, 1, 128)    0           global_average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 1, 1, 16)     2048        reshape_5[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 1, 1, 128)    2048        dense_10[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 72, 96, 128)  0           activation_19[0][0]
#                                                                  dense_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 36, 48, 128)  0           multiply_5[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 1, 1, 128)    0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 1, 1, 64)     8256        average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 1, 1, 64)     256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 36, 48, 64)   8192        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 36, 48, 64)   73728       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 36, 48, 64)   73728       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 36, 48, 64)   73728       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 1, 1, 64)     0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 36, 48, 64)   256         conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 36, 48, 64)   256         conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 36, 48, 64)   256         conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 36, 48, 64)   256         conv2d_24[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 36, 48, 64)   0           activation_20[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 36, 48, 64)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 36, 48, 64)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 36, 48, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 36, 48, 64)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 36, 48, 320)  0           up_sampling2d_4[0][0]
#                                                                  activation_21[0][0]
#                                                                  activation_22[0][0]
#                                                                  activation_23[0][0]
#                                                                  activation_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 36, 48, 64)   20480       concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 36, 48, 64)   256         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 36, 48, 64)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 36, 48, 256)  147712      activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 36, 48, 256)  1024        conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 36, 48, 256)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 36, 48, 256)  590080      activation_26[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 36, 48, 256)  0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 72, 96, 256)  0           activation_27[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 72, 96, 640)  0           up_sampling2d_5[0][0]
#                                                                  block3_conv3[0][0]
#                                                                  multiply_5[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 72, 96, 128)  737408      concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 72, 96, 128)  512         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 72, 96, 128)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 72, 96, 128)  147584      activation_28[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 72, 96, 128)  0           conv2d_29[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_6 (Glo (None, 128)          0           activation_29[0][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 1, 1, 128)    0           global_average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 1, 1, 16)     2048        reshape_6[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 1, 1, 128)    2048        dense_12[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 72, 96, 128)  0           activation_29[0][0]
#                                                                  dense_13[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 144, 192, 128 0           multiply_6[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 144, 192, 320 0           up_sampling2d_6[0][0]
#                                                                  block2_conv2[0][0]
#                                                                  multiply_4[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 144, 192, 64) 184384      concatenate_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 144, 192, 64) 256         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 144, 192, 64) 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 144, 192, 64) 36928       activation_30[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 144, 192, 64) 0           conv2d_31[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_7 (Glo (None, 64)           0           activation_31[0][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (None, 1, 1, 64)     0           global_average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 1, 1, 8)      512         reshape_7[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 1, 1, 64)     512         dense_14[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 144, 192, 64) 0           activation_31[0][0]
#                                                                  dense_15[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_7 (UpSampling2D)  (None, 288, 384, 64) 0           multiply_7[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 288, 384, 160 0           up_sampling2d_7[0][0]
#                                                                  block1_conv2[0][0]
#                                                                  multiply_3[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 288, 384, 32) 46112       concatenate_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 288, 384, 32) 128         conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 288, 384, 32) 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 288, 384, 32) 9248        activation_32[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 288, 384, 32) 0           conv2d_33[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_8 (Glo (None, 32)           0           activation_33[0][0]
# __________________________________________________________________________________________________
# reshape_8 (Reshape)             (None, 1, 1, 32)     0           global_average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 1, 1, 4)      128         reshape_8[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 1, 1, 32)     128         dense_16[0][0]
# __________________________________________________________________________________________________
# multiply_8 (Multiply)           (None, 288, 384, 32) 0           activation_33[0][0]
#                                                                  dense_17[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 288, 384, 2)  578         multiply_8[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 288, 384, 2)  0           conv2d_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 288, 384, 1)  3           activation_34[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 288, 384, 1)  0           conv2d_35[0][0]
# ==================================================================================================
# Total params: 12,411,178
# Trainable params: 12,407,786
# Non-trainable params: 3,392
# __________________________________________________________________________________________________

# %%
loss      = metrics.bce_dice_loss
recall    = tf.keras.metrics.Recall()
precision = tf.keras.metrics.Precision()
metric    = [metrics.dice, metrics.iou, recall, precision]

print(f'Model wil be saved in {model_weights}')

train_history, model = lib.train(model_weights, log_path, params, model, loss, metric, train_generator, val_generator)
train_history = train_history.history
# Out:
# Model wil be saved in /content/drive/MyDrive/CVDL/dataset/results/models/dbunet_BN_vgg16_Glorot_e100_lr0.001
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 1/100
# 21/21 [==============================] - 46s 1s/step - loss: 1.2372 - dice: 0.0362 - iou: 0.0019 - recall: 0.0442 - precision: 0.0258 - val_loss: 1.0973 - val_dice: 0.0014 - val_iou: 9.3000e-09 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00
#
# Epoch 00001: val_loss improved from inf to 1.09727, saving model to /content/drive/MyDrive/CVDL/dataset/results/models/dbunet_BN_vgg16_Glorot_e100_lr0.001/Model.hdf5
# Epoch 2/100
# 21/21 [==============================] - 11s 547ms/step - loss: 0.7613 - dice: 0.2720 - iou: 1.0036e-08 - recall: 0.0000e+00 - precision: 0.0000e+00 - val_loss: 1.0895 - val_dice: 0.0047 - val_iou: 9.3320e-09 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00
#
# Epoch 00002: val_loss improved from 1.09727 to 1.08950, saving model to /content/drive/MyDrive/CVDL/dataset/results/models/dbunet_BN_vgg16_Glorot_e100_lr0.001/Model.hdf5
# Epoch 3/100
# 21/21 [==============================] - 11s 546ms/step - loss: 0.6064 - dice: 0.4204 - iou: 0.0056 - recall: 0.0048 - precision: 0.7434 - val_loss: 0.7996 - val_dice: 0.2499 - val_iou: 0.0332 - val_recall: 0.0327 - val_precision: 0.6078
#
# Epoch 00003: val_loss improved from 1.08950 to 0.79965, saving model to /content/drive/MyDrive/CVDL/dataset/results/models/dbunet_BN_vgg16_Glorot_e100_lr0.001/Model.hdf5
# Epoch 4/100
# 21/21 [==============================] - 11s 516ms/step - loss: 0.5421 - dice: 0.4799 - iou: 0.5226 - recall: 0.5371 - precision: 0.7933 - val_loss: 0.6779 - val_dice: 0.3669 - val_iou: 0.3178 - val_recall: 0.5029 - val_precision: 0.4813
#
# Epoch 00004: val_loss improved from 0.79965 to 0.67789, saving model to /content/drive/MyDrive/CVDL/dataset/results/models/dbunet_BN_vgg16_Glorot_e100_lr0.001/Model.hdf5
# Epoch 5/100
# 21/21 [==============================] - 11s 546ms/step - loss: 0.4714 - dice: 0.5503 - iou: 0.6280 - recall: 0.6476 - precision: 0.8185 - val_loss: 0.5419 - val_dice: 0.4932 - val_iou: 0.4852 - val_recall: 0.5834 - val_precision: 0.6708
#
# Epoch 00005: val_loss improved from 0.67789 to 0.54189, saving model to /content/drive/MyDrive/CVDL/dataset/results/models/dbunet_BN_vgg16_Glorot_e100_lr0.001/Model.hdf5
# Epoch 6/100
# 21/21 [==============================] - 11s 514ms/step - loss: 0.2870 - dice: 0.7376 - iou: 0.6540 - recall: 0.7067 - precision: 0.8311 - val_loss: 0.4683 - val_dice: 0.5858 - val_iou: 0.4401 - val_recall: 0.7894 - val_precision: 0.4882
#
# Epoch 00006: val_loss improved from 0.54189 to 0.46832, saving model to /content/drive/MyDrive/CVDL/dataset/results/models/dbunet_BN_vgg16_Glorot_e100_lr0.001/Model.hdf5
# Epoch 7/100
# 21/21 [==============================] - 11s 518ms/step - loss: 0.2413 - dice: 0.7850 - iou: 0.6754 - recall: 0.7138 - precision: 0.8447 - val_loss: 0.4460 - val_dice: 0.5884 - val_iou: 0.4773 - val_recall: 0.4618 - val_precision: 0.8278
#
# Epoch 00007: val_loss improved from 0.46832 to 0.44597, saving model to /content/drive/MyDrive/CVDL/dataset/results/models/dbunet_BN_vgg16_Glorot_e100_lr0.001/Model.hdf5
# Epoch 8/100
# 21/21 [==============================] - 11s 548ms/step - loss: 0.2287 - dice: 0.7921 - iou: 0.6889 - recall: 0.7259 - precision: 0.8566 - val_loss: 0.4048 - val_dice: 0.6245 - val_iou: 0.5209 - val_recall: 0.5246 - val_precision: 0.8741
#
# Epoch 00008: val_loss improved from 0.44597 to 0.40481, saving model to /content/drive/MyDrive/CVDL/dataset/results/models/dbunet_BN_vgg16_Glorot_e100_lr0.001/Model.hdf5
# Epoch 9/100
# 21/21 [==============================] - 11s 548ms/step - loss: 0.2068 - dice: 0.8143 - iou: 0.7156 - recall: 0.7417 - precision: 0.8693 - val_loss: 0.3758 - val_dice: 0.6578 - val_iou: 0.5322 - val_recall: 0.6647 - val_precision: 0.6666
#
# Epoch 00009: val_loss improved from 0.40481 to 0.37578, saving model to /content/drive/MyDrive/CVDL/dataset/results/models/dbunet_BN_vgg16_Glorot_e100_lr0.001/Model.hdf5
# Epoch 10/100
# 21/21 [==============================] - 11s 549ms/step - loss: 0.1888 - dice: 0.8245 - iou: 0.7338 - recall: 0.7583 - precision: 0.8966 - val_loss: 0.3638 - val_dice: 0.6698 - val_iou: 0.5636 - val_recall: 0.5868 - val_precision: 0.7962
#
# Epoch 00010: val_loss improved from 0.37578 to 0.36376, saving model to /content/drive/MyDrive/CVDL/dataset/results/models/dbunet_BN_vgg16_Glorot_e100_lr0.001/Model.hdf5
# Epoch 11/100
# 21/21 [==============================] - 11s 519ms/step - loss: 0.1825 - dice: 0.8335 - iou: 0.7399 - recall: 0.7759 - precision: 0.8766 - val_loss: 0.3990 - val_dice: 0.6457 - val_iou: 0.5432 - val_recall: 0.5262 - val_precision: 0.8167
#
# Epoch 00011: val_loss did not improve from 0.36376
# Epoch 12/100
# 21/21 [==============================] - 11s 516ms/step - loss: 0.1812 - dice: 0.8323 - iou: 0.7433 - recall: 0.7587 - precision: 0.8992 - val_loss: 0.3195 - val_dice: 0.7056 - val_iou: 0.6257 - val_recall: 0.5526 - val_precision: 0.9737
#
# Epoch 00012: val_loss improved from 0.36376 to 0.31953, saving model to /content/drive/MyDrive/CVDL/dataset/results/models/dbunet_BN_vgg16_Glorot_e100_lr0.001/Model.hdf5
# Epoch 13/100
# 21/21 [==============================] - 11s 547ms/step - loss: 0.1598 - dice: 0.8527 - iou: 0.7661 - recall: 0.7870 - precision: 0.9065 - val_loss: 0.5415 - val_dice: 0.5072 - val_iou: 0.3862 - val_recall: 0.3377 - val_precision: 0.9809
#
# Epoch 00013: val_loss did not improve from 0.31953
# Epoch 14/100
# 21/21 [==============================] - 11s 515ms/step - loss: 0.1670 - dice: 0.8473 - iou: 0.7587 - recall: 0.7777 - precision: 0.9058 - val_loss: 0.2553 - val_dice: 0.7654 - val_iou: 0.6945 - val_recall: 0.6586 - val_precision: 0.9360
#
# Epoch 00014: val_loss improved from 0.31953 to 0.25531, saving model to /content/drive/MyDrive/CVDL/dataset/results/models/dbunet_BN_vgg16_Glorot_e100_lr0.001/Model.hdf5
# Epoch 15/100
# 21/21 [==============================] - 11s 548ms/step - loss: 0.1931 - dice: 0.8247 - iou: 0.7334 - recall: 0.7566 - precision: 0.8763 - val_loss: 0.4059 - val_dice: 0.6239 - val_iou: 0.5722 - val_recall: 0.5194 - val_precision: 0.8536
#
# Epoch 00015: val_loss did not improve from 0.25531
# Epoch 16/100
# 21/21 [==============================] - 11s 516ms/step - loss: 0.1653 - dice: 0.8506 - iou: 0.7627 - recall: 0.7903 - precision: 0.9031 - val_loss: 0.4159 - val_dice: 0.6458 - val_iou: 0.5365 - val_recall: 0.4704 - val_precision: 0.9838
#
# Epoch 00016: val_loss did not improve from 0.25531
# Epoch 17/100
# 21/21 [==============================] - 11s 548ms/step - loss: 0.1618 - dice: 0.8519 - iou: 0.7689 - recall: 0.7802 - precision: 0.9107 - val_loss: 0.3339 - val_dice: 0.7164 - val_iou: 0.6300 - val_recall: 0.6131 - val_precision: 0.8499
#
# Epoch 00017: val_loss did not improve from 0.25531
# Epoch 18/100
# 21/21 [==============================] - 11s 518ms/step - loss: 0.1449 - dice: 0.8663 - iou: 0.7871 - recall: 0.8003 - precision: 0.9230 - val_loss: 0.2160 - val_dice: 0.8054 - val_iou: 0.7178 - val_recall: 0.7594 - val_precision: 0.8628
#
# Epoch 00018: val_loss improved from 0.25531 to 0.21603, saving model to /content/drive/MyDrive/CVDL/dataset/results/models/dbunet_BN_vgg16_Glorot_e100_lr0.001/Model.hdf5
# Epoch 19/100
# 21/21 [==============================] - 11s 520ms/step - loss: 0.1362 - dice: 0.8746 - iou: 0.8029 - recall: 0.8033 - precision: 0.9305 - val_loss: 0.1622 - val_dice: 0.8533 - val_iou: 0.7735 - val_recall: 0.7993 - val_precision: 0.9112
#
# Epoch 00019: val_loss improved from 0.21603 to 0.16222, saving model to /content/drive/MyDrive/CVDL/dataset/results/models/dbunet_BN_vgg16_Glorot_e100_lr0.001/Model.hdf5
# Epoch 20/100
# 21/21 [==============================] - 11s 516ms/step - loss: 0.1217 - dice: 0.8888 - iou: 0.8157 - recall: 0.8143 - precision: 0.9397 - val_loss: 0.2154 - val_dice: 0.8102 - val_iou: 0.7516 - val_recall: 0.7123 - val_precision: 0.9336
#
# Epoch 00020: val_loss did not improve from 0.16222
# Epoch 21/100
# 21/21 [==============================] - 11s 548ms/step - loss: 0.1259 - dice: 0.8839 - iou: 0.8135 - recall: 0.8192 - precision: 0.9350 - val_loss: 0.2127 - val_dice: 0.8071 - val_iou: 0.7462 - val_recall: 0.7610 - val_precision: 0.8732
#
# Epoch 00021: val_loss did not improve from 0.16222
# Epoch 22/100
# 21/21 [==============================] - 11s 548ms/step - loss: 0.1369 - dice: 0.8748 - iou: 0.7959 - recall: 0.7986 - precision: 0.9324 - val_loss: 0.1779 - val_dice: 0.8428 - val_iou: 0.7692 - val_recall: 0.7788 - val_precision: 0.9137
#
# Epoch 00022: val_loss did not improve from 0.16222
# Epoch 23/100
# 21/21 [==============================] - 11s 547ms/step - loss: 0.1183 - dice: 0.8917 - iou: 0.8249 - recall: 0.8214 - precision: 0.9411 - val_loss: 0.2002 - val_dice: 0.8231 - val_iou: 0.7483 - val_recall: 0.7228 - val_precision: 0.9340
#
# Epoch 00023: val_loss did not improve from 0.16222
# Epoch 24/100
# 21/21 [==============================] - 11s 516ms/step - loss: 0.1104 - dice: 0.8994 - iou: 0.8316 - recall: 0.8295 - precision: 0.9522 - val_loss: 0.3040 - val_dice: 0.7369 - val_iou: 0.6719 - val_recall: 0.6989 - val_precision: 0.7955
#
# Epoch 00024: val_loss did not improve from 0.16222
# Epoch 25/100
# 21/21 [==============================] - 11s 516ms/step - loss: 0.1327 - dice: 0.8790 - iou: 0.8067 - recall: 0.8017 - precision: 0.9335 - val_loss: 0.2090 - val_dice: 0.8207 - val_iou: 0.7128 - val_recall: 0.8412 - val_precision: 0.8086
#
# Epoch 00025: val_loss did not improve from 0.16222
# Epoch 26/100
# 21/21 [==============================] - 11s 515ms/step - loss: 0.1187 - dice: 0.8905 - iou: 0.8230 - recall: 0.8225 - precision: 0.9420 - val_loss: 0.1643 - val_dice: 0.8537 - val_iou: 0.7889 - val_recall: 0.7850 - val_precision: 0.9419
#
# Epoch 00026: val_loss did not improve from 0.16222
# Epoch 27/100
# 21/21 [==============================] - 11s 518ms/step - loss: 0.1081 - dice: 0.9006 - iou: 0.8323 - recall: 0.8323 - precision: 0.9529 - val_loss: 0.1433 - val_dice: 0.8653 - val_iou: 0.7968 - val_recall: 0.8594 - val_precision: 0.8882
#
# Epoch 00027: val_loss improved from 0.16222 to 0.14328, saving model to /content/drive/MyDrive/CVDL/dataset/results/models/dbunet_BN_vgg16_Glorot_e100_lr0.001/Model.hdf5
# Epoch 28/100
# 21/21 [==============================] - 11s 515ms/step - loss: 0.1168 - dice: 0.8928 - iou: 0.8264 - recall: 0.8198 - precision: 0.9451 - val_loss: 0.2660 - val_dice: 0.7749 - val_iou: 0.7087 - val_recall: 0.6158 - val_precision: 0.9711
#
# Epoch 00028: val_loss did not improve from 0.14328
# Epoch 29/100
# 21/21 [==============================] - 11s 515ms/step - loss: 0.1491 - dice: 0.8611 - iou: 0.7793 - recall: 0.8033 - precision: 0.9055 - val_loss: 0.1639 - val_dice: 0.8536 - val_iou: 0.7555 - val_recall: 0.8669 - val_precision: 0.8522
#
# Epoch 00029: val_loss did not improve from 0.14328
# Epoch 30/100
# 21/21 [==============================] - 11s 546ms/step - loss: 0.1205 - dice: 0.8884 - iou: 0.8212 - recall: 0.8122 - precision: 0.9501 - val_loss: 0.1525 - val_dice: 0.8646 - val_iou: 0.7851 - val_recall: 0.8880 - val_precision: 0.8489
#
# Epoch 00030: val_loss did not improve from 0.14328
# Epoch 31/100
# 21/21 [==============================] - 11s 546ms/step - loss: 0.1201 - dice: 0.8904 - iou: 0.8194 - recall: 0.8288 - precision: 0.9346 - val_loss: 0.1537 - val_dice: 0.8678 - val_iou: 0.8083 - val_recall: 0.7747 - val_precision: 0.9526
#
# Epoch 00031: val_loss did not improve from 0.14328
# Epoch 32/100
# 21/21 [==============================] - 11s 543ms/step - loss: 0.1190 - dice: 0.8909 - iou: 0.8247 - recall: 0.8208 - precision: 0.9397 - val_loss: 0.2078 - val_dice: 0.8135 - val_iou: 0.7372 - val_recall: 0.7157 - val_precision: 0.9388
#
# Epoch 00032: val_loss did not improve from 0.14328
# Epoch 33/100
# 21/21 [==============================] - 11s 517ms/step - loss: 0.1175 - dice: 0.8905 - iou: 0.8225 - recall: 0.8165 - precision: 0.9500 - val_loss: 0.1294 - val_dice: 0.8819 - val_iou: 0.7975 - val_recall: 0.8747 - val_precision: 0.8981
#
# Epoch 00033: val_loss improved from 0.14328 to 0.12945, saving model to /content/drive/MyDrive/CVDL/dataset/results/models/dbunet_BN_vgg16_Glorot_e100_lr0.001/Model.hdf5
# Epoch 34/100
# 21/21 [==============================] - 11s 517ms/step - loss: 0.1196 - dice: 0.8897 - iou: 0.8192 - recall: 0.8355 - precision: 0.9307 - val_loss: 0.1411 - val_dice: 0.8752 - val_iou: 0.8238 - val_recall: 0.8102 - val_precision: 0.9351
#
# Epoch 00034: val_loss did not improve from 0.12945
# Epoch 35/100
# 21/21 [==============================] - 11s 547ms/step - loss: 0.1178 - dice: 0.8915 - iou: 0.8194 - recall: 0.8206 - precision: 0.9401 - val_loss: 0.1468 - val_dice: 0.8701 - val_iou: 0.8137 - val_recall: 0.8392 - val_precision: 0.9145
#
# Epoch 00035: val_loss did not improve from 0.12945
# Epoch 36/100
# 21/21 [==============================] - 11s 516ms/step - loss: 0.1199 - dice: 0.8910 - iou: 0.8214 - recall: 0.8163 - precision: 0.9418 - val_loss: 0.1386 - val_dice: 0.8751 - val_iou: 0.7952 - val_recall: 0.8715 - val_precision: 0.8781
#
# Epoch 00036: val_loss did not improve from 0.12945
# Epoch 37/100
# 21/21 [==============================] - 11s 515ms/step - loss: 0.1105 - dice: 0.8958 - iou: 0.8261 - recall: 0.8272 - precision: 0.9531 - val_loss: 0.1066 - val_dice: 0.9005 - val_iou: 0.8369 - val_recall: 0.8846 - val_precision: 0.9275
#
# Epoch 00037: val_loss improved from 0.12945 to 0.10660, saving model to /content/drive/MyDrive/CVDL/dataset/results/models/dbunet_BN_vgg16_Glorot_e100_lr0.001/Model.hdf5
# Epoch 38/100
# 21/21 [==============================] - 11s 517ms/step - loss: 0.1304 - dice: 0.8796 - iou: 0.8102 - recall: 0.8163 - precision: 0.9239 - val_loss: 0.1827 - val_dice: 0.8292 - val_iou: 0.7464 - val_recall: 0.8409 - val_precision: 0.8334
#
# Epoch 00038: val_loss did not improve from 0.10660
# Epoch 39/100
# 21/21 [==============================] - 11s 549ms/step - loss: 0.1048 - dice: 0.9042 - iou: 0.8397 - recall: 0.8221 - precision: 0.9645 - val_loss: 0.1510 - val_dice: 0.8661 - val_iou: 0.8156 - val_recall: 0.8068 - val_precision: 0.9255
#
# Epoch 00039: val_loss did not improve from 0.10660
# Epoch 40/100
# 21/21 [==============================] - 11s 515ms/step - loss: 0.1063 - dice: 0.9022 - iou: 0.8365 - recall: 0.8261 - precision: 0.9591 - val_loss: 0.1301 - val_dice: 0.8834 - val_iou: 0.8110 - val_recall: 0.8579 - val_precision: 0.9008
#
# Epoch 00040: val_loss did not improve from 0.10660
# Epoch 41/100
# 21/21 [==============================] - 11s 515ms/step - loss: 0.1044 - dice: 0.9044 - iou: 0.8422 - recall: 0.8265 - precision: 0.9571 - val_loss: 0.1382 - val_dice: 0.8783 - val_iou: 0.8168 - val_recall: 0.8065 - val_precision: 0.9504
#
# Epoch 00041: val_loss did not improve from 0.10660
# Epoch 42/100
# 21/21 [==============================] - 11s 514ms/step - loss: 0.0971 - dice: 0.9107 - iou: 0.8521 - recall: 0.8413 - precision: 0.9623 - val_loss: 0.1764 - val_dice: 0.8443 - val_iou: 0.7904 - val_recall: 0.7858 - val_precision: 0.8973
#
# Epoch 00042: val_loss did not improve from 0.10660
# Epoch 43/100
# 21/21 [==============================] - 11s 517ms/step - loss: 0.0914 - dice: 0.9154 - iou: 0.8584 - recall: 0.8401 - precision: 0.9690 - val_loss: 0.1368 - val_dice: 0.8798 - val_iou: 0.8094 - val_recall: 0.7997 - val_precision: 0.9573
#
# Epoch 00043: val_loss did not improve from 0.10660
# Epoch 44/100
# 21/21 [==============================] - 11s 518ms/step - loss: 0.0935 - dice: 0.9145 - iou: 0.8560 - recall: 0.8389 - precision: 0.9669 - val_loss: 0.1959 - val_dice: 0.8235 - val_iou: 0.7831 - val_recall: 0.7344 - val_precision: 0.9270
#
# Epoch 00044: val_loss did not improve from 0.10660
# Epoch 45/100
# 21/21 [==============================] - 11s 516ms/step - loss: 0.0965 - dice: 0.9115 - iou: 0.8526 - recall: 0.8377 - precision: 0.9616 - val_loss: 0.2277 - val_dice: 0.8065 - val_iou: 0.7562 - val_recall: 0.6781 - val_precision: 0.9553
#
# Epoch 00045: val_loss did not improve from 0.10660
# Epoch 46/100
# 21/21 [==============================] - 11s 544ms/step - loss: 0.1020 - dice: 0.9054 - iou: 0.8440 - recall: 0.8314 - precision: 0.9607 - val_loss: 0.2057 - val_dice: 0.8260 - val_iou: 0.7670 - val_recall: 0.6918 - val_precision: 0.9836
#
# Epoch 00046: val_loss did not improve from 0.10660
# Epoch 47/100
# 21/21 [==============================] - 11s 546ms/step - loss: 0.1047 - dice: 0.9047 - iou: 0.8412 - recall: 0.8353 - precision: 0.9545 - val_loss: 0.1153 - val_dice: 0.8987 - val_iou: 0.8439 - val_recall: 0.8415 - val_precision: 0.9560
#
# Epoch 00047: val_loss did not improve from 0.10660
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 48/100
# 21/21 [==============================] - 11s 515ms/step - loss: 0.0944 - dice: 0.9130 - iou: 0.8519 - recall: 0.8314 - precision: 0.9672 - val_loss: 0.2079 - val_dice: 0.8252 - val_iou: 0.7768 - val_recall: 0.7386 - val_precision: 0.9164
#
# Epoch 00048: val_loss did not improve from 0.10660
# Epoch 49/100
# 21/21 [==============================] - 11s 545ms/step - loss: 0.0891 - dice: 0.9177 - iou: 0.8644 - recall: 0.8450 - precision: 0.9703 - val_loss: 0.1618 - val_dice: 0.8649 - val_iou: 0.8133 - val_recall: 0.7902 - val_precision: 0.9403
#
# Epoch 00049: val_loss did not improve from 0.10660
# Epoch 50/100
# 21/21 [==============================] - 11s 548ms/step - loss: 0.0883 - dice: 0.9184 - iou: 0.8644 - recall: 0.8517 - precision: 0.9676 - val_loss: 0.1629 - val_dice: 0.8608 - val_iou: 0.8053 - val_recall: 0.7974 - val_precision: 0.9238
#
# Epoch 00050: val_loss did not improve from 0.10660
# Epoch 51/100
# 21/21 [==============================] - 11s 547ms/step - loss: 0.0857 - dice: 0.9212 - iou: 0.8700 - recall: 0.8454 - precision: 0.9737 - val_loss: 0.1562 - val_dice: 0.8671 - val_iou: 0.8151 - val_recall: 0.7969 - val_precision: 0.9339
#
# Epoch 00051: val_loss did not improve from 0.10660
# Epoch 52/100
# 21/21 [==============================] - 11s 516ms/step - loss: 0.0841 - dice: 0.9224 - iou: 0.8706 - recall: 0.8434 - precision: 0.9749 - val_loss: 0.1673 - val_dice: 0.8589 - val_iou: 0.8109 - val_recall: 0.7916 - val_precision: 0.9160
#
# Epoch 00052: val_loss did not improve from 0.10660
# Epoch 53/100
# 21/21 [==============================] - 11s 548ms/step - loss: 0.0846 - dice: 0.9212 - iou: 0.8678 - recall: 0.8550 - precision: 0.9685 - val_loss: 0.1578 - val_dice: 0.8643 - val_iou: 0.8116 - val_recall: 0.7992 - val_precision: 0.9284
#
# Epoch 00053: val_loss did not improve from 0.10660
# Epoch 54/100
# 21/21 [==============================] - 11s 517ms/step - loss: 0.0848 - dice: 0.9218 - iou: 0.8707 - recall: 0.8397 - precision: 0.9758 - val_loss: 0.1440 - val_dice: 0.8739 - val_iou: 0.8152 - val_recall: 0.8008 - val_precision: 0.9566
#
# Epoch 00054: val_loss did not improve from 0.10660
# Epoch 55/100
# 21/21 [==============================] - 11s 515ms/step - loss: 0.0857 - dice: 0.9215 - iou: 0.8711 - recall: 0.8400 - precision: 0.9745 - val_loss: 0.1616 - val_dice: 0.8599 - val_iou: 0.8084 - val_recall: 0.7950 - val_precision: 0.9283
#
# Epoch 00055: val_loss did not improve from 0.10660
# Epoch 56/100
# 21/21 [==============================] - 11s 517ms/step - loss: 0.0843 - dice: 0.9223 - iou: 0.8701 - recall: 0.8505 - precision: 0.9728 - val_loss: 0.1575 - val_dice: 0.8672 - val_iou: 0.8174 - val_recall: 0.7968 - val_precision: 0.9343
#
# Epoch 00056: val_loss did not improve from 0.10660
# Epoch 57/100
# 21/21 [==============================] - 11s 516ms/step - loss: 0.0849 - dice: 0.9221 - iou: 0.8682 - recall: 0.8440 - precision: 0.9746 - val_loss: 0.1773 - val_dice: 0.8430 - val_iou: 0.8040 - val_recall: 0.7751 - val_precision: 0.9370
#
# Epoch 00057: val_loss did not improve from 0.10660
#
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 58/100
# 21/21 [==============================] - 11s 546ms/step - loss: 0.0821 - dice: 0.9245 - iou: 0.8748 - recall: 0.8482 - precision: 0.9754 - val_loss: 0.1471 - val_dice: 0.8737 - val_iou: 0.8221 - val_recall: 0.8052 - val_precision: 0.9332
#
# Epoch 00058: val_loss did not improve from 0.10660
# Epoch 59/100
# 21/21 [==============================] - 11s 549ms/step - loss: 0.0825 - dice: 0.9235 - iou: 0.8724 - recall: 0.8480 - precision: 0.9742 - val_loss: 0.1634 - val_dice: 0.8608 - val_iou: 0.8041 - val_recall: 0.7869 - val_precision: 0.9335
#
# Epoch 00059: val_loss did not improve from 0.10660
# Epoch 60/100
# 21/21 [==============================] - 11s 548ms/step - loss: 0.0827 - dice: 0.9231 - iou: 0.8736 - recall: 0.8496 - precision: 0.9745 - val_loss: 0.1567 - val_dice: 0.8669 - val_iou: 0.8086 - val_recall: 0.7937 - val_precision: 0.9293
#
# Epoch 00060: val_loss did not improve from 0.10660
# Epoch 61/100
# 21/21 [==============================] - 11s 548ms/step - loss: 0.0812 - dice: 0.9251 - iou: 0.8737 - recall: 0.8440 - precision: 0.9792 - val_loss: 0.1595 - val_dice: 0.8557 - val_iou: 0.8096 - val_recall: 0.7941 - val_precision: 0.9350
#
# Epoch 00061: val_loss did not improve from 0.10660
# Epoch 62/100
# 21/21 [==============================] - 11s 548ms/step - loss: 0.0840 - dice: 0.9224 - iou: 0.8725 - recall: 0.8496 - precision: 0.9735 - val_loss: 0.1487 - val_dice: 0.8650 - val_iou: 0.8121 - val_recall: 0.7992 - val_precision: 0.9285
#
# Epoch 00062: val_loss did not improve from 0.10660
# Epoch 63/100
# 21/21 [==============================] - 11s 516ms/step - loss: 0.0824 - dice: 0.9239 - iou: 0.8702 - recall: 0.8484 - precision: 0.9757 - val_loss: 0.1869 - val_dice: 0.8423 - val_iou: 0.7909 - val_recall: 0.7723 - val_precision: 0.9039
#
# Epoch 00063: val_loss did not improve from 0.10660
# Epoch 64/100
# 21/21 [==============================] - 11s 548ms/step - loss: 0.0842 - dice: 0.9222 - iou: 0.8705 - recall: 0.8510 - precision: 0.9726 - val_loss: 0.1606 - val_dice: 0.8629 - val_iou: 0.8138 - val_recall: 0.7964 - val_precision: 0.9351
#
# Epoch 00064: val_loss did not improve from 0.10660
# Epoch 65/100
# 21/21 [==============================] - 11s 546ms/step - loss: 0.0794 - dice: 0.9266 - iou: 0.8768 - recall: 0.8496 - precision: 0.9776 - val_loss: 0.1510 - val_dice: 0.8726 - val_iou: 0.8157 - val_recall: 0.7936 - val_precision: 0.9374
#
# Epoch 00065: val_loss did not improve from 0.10660
# Epoch 66/100
# 21/21 [==============================] - 11s 546ms/step - loss: 0.0822 - dice: 0.9239 - iou: 0.8726 - recall: 0.8480 - precision: 0.9750 - val_loss: 0.1565 - val_dice: 0.8597 - val_iou: 0.8117 - val_recall: 0.7967 - val_precision: 0.9339
#
# Epoch 00066: val_loss did not improve from 0.10660
# Epoch 67/100
# 21/21 [==============================] - 11s 547ms/step - loss: 0.0833 - dice: 0.9230 - iou: 0.8727 - recall: 0.8514 - precision: 0.9716 - val_loss: 0.2118 - val_dice: 0.8249 - val_iou: 0.7763 - val_recall: 0.7347 - val_precision: 0.9149
#
# Epoch 00067: val_loss did not improve from 0.10660
#
# Epoch 00067: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 68/100
# 21/21 [==============================] - 11s 516ms/step - loss: 0.0831 - dice: 0.9219 - iou: 0.8705 - recall: 0.8463 - precision: 0.9758 - val_loss: 0.1127 - val_dice: 0.9031 - val_iou: 0.8480 - val_recall: 0.8437 - val_precision: 0.9569
#
# Epoch 00068: val_loss did not improve from 0.10660
# Epoch 69/100
# 21/21 [==============================] - 11s 517ms/step - loss: 0.0835 - dice: 0.9233 - iou: 0.8719 - recall: 0.8473 - precision: 0.9745 - val_loss: 0.1549 - val_dice: 0.8664 - val_iou: 0.8192 - val_recall: 0.8101 - val_precision: 0.9272
#
# Epoch 00069: val_loss did not improve from 0.10660
# Epoch 70/100
# 21/21 [==============================] - 11s 546ms/step - loss: 0.0850 - dice: 0.9210 - iou: 0.8685 - recall: 0.8462 - precision: 0.9734 - val_loss: 0.1574 - val_dice: 0.8655 - val_iou: 0.8182 - val_recall: 0.7993 - val_precision: 0.9355
#
# Epoch 00070: val_loss did not improve from 0.10660
# Epoch 71/100
# 21/21 [==============================] - 11s 547ms/step - loss: 0.0823 - dice: 0.9240 - iou: 0.8735 - recall: 0.8523 - precision: 0.9734 - val_loss: 0.1563 - val_dice: 0.8654 - val_iou: 0.8148 - val_recall: 0.7994 - val_precision: 0.9324
#
# Epoch 00071: val_loss did not improve from 0.10660
# Epoch 72/100
# 21/21 [==============================] - 11s 516ms/step - loss: 0.0852 - dice: 0.9216 - iou: 0.8691 - recall: 0.8467 - precision: 0.9714 - val_loss: 0.1715 - val_dice: 0.8541 - val_iou: 0.8089 - val_recall: 0.7851 - val_precision: 0.9287
#
# Epoch 00072: val_loss did not improve from 0.10660
# Epoch 73/100
# 21/21 [==============================] - 11s 516ms/step - loss: 0.0807 - dice: 0.9251 - iou: 0.8751 - recall: 0.8505 - precision: 0.9763 - val_loss: 0.1309 - val_dice: 0.8772 - val_iou: 0.8254 - val_recall: 0.8201 - val_precision: 0.9407
#
# Epoch 00073: val_loss did not improve from 0.10660
# Epoch 74/100
# 21/21 [==============================] - 11s 516ms/step - loss: 0.0803 - dice: 0.9263 - iou: 0.8773 - recall: 0.8511 - precision: 0.9767 - val_loss: 0.1581 - val_dice: 0.8616 - val_iou: 0.8111 - val_recall: 0.8009 - val_precision: 0.9271
#
# Epoch 00074: val_loss did not improve from 0.10660
# Epoch 75/100
# 21/21 [==============================] - 11s 548ms/step - loss: 0.0846 - dice: 0.9213 - iou: 0.8660 - recall: 0.8481 - precision: 0.9719 - val_loss: 0.1540 - val_dice: 0.8698 - val_iou: 0.8160 - val_recall: 0.8025 - val_precision: 0.9312
#
# Epoch 00075: val_loss did not improve from 0.10660
# Epoch 76/100
# 21/21 [==============================] - 11s 518ms/step - loss: 0.0827 - dice: 0.9240 - iou: 0.8748 - recall: 0.8470 - precision: 0.9770 - val_loss: 0.1571 - val_dice: 0.8626 - val_iou: 0.8148 - val_recall: 0.8000 - val_precision: 0.9323
#
# Epoch 00076: val_loss did not improve from 0.10660
# Epoch 77/100
# 21/21 [==============================] - 11s 548ms/step - loss: 0.0828 - dice: 0.9242 - iou: 0.8748 - recall: 0.8492 - precision: 0.9742 - val_loss: 0.1539 - val_dice: 0.8685 - val_iou: 0.8194 - val_recall: 0.8071 - val_precision: 0.9273
#
# Epoch 00077: val_loss did not improve from 0.10660
#
# Epoch 00077: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# Epoch 78/100
# 21/21 [==============================] - 11s 515ms/step - loss: 0.0839 - dice: 0.9229 - iou: 0.8719 - recall: 0.8490 - precision: 0.9731 - val_loss: 0.1540 - val_dice: 0.8647 - val_iou: 0.8096 - val_recall: 0.8039 - val_precision: 0.9303
#
# Epoch 00078: val_loss did not improve from 0.10660
# Epoch 79/100
# 21/21 [==============================] - 11s 515ms/step - loss: 0.0848 - dice: 0.9217 - iou: 0.8701 - recall: 0.8461 - precision: 0.9738 - val_loss: 0.2137 - val_dice: 0.8152 - val_iou: 0.7707 - val_recall: 0.7318 - val_precision: 0.9167
#
# Epoch 00079: val_loss did not improve from 0.10660
# Epoch 80/100
# 21/21 [==============================] - 11s 549ms/step - loss: 0.0787 - dice: 0.9276 - iou: 0.8800 - recall: 0.8504 - precision: 0.9786 - val_loss: 0.1453 - val_dice: 0.8763 - val_iou: 0.8294 - val_recall: 0.8088 - val_precision: 0.9348
#
# Epoch 00080: val_loss did not improve from 0.10660
# Epoch 81/100
# 21/21 [==============================] - 11s 517ms/step - loss: 0.0848 - dice: 0.9213 - iou: 0.8697 - recall: 0.8508 - precision: 0.9698 - val_loss: 0.1521 - val_dice: 0.8706 - val_iou: 0.8161 - val_recall: 0.7999 - val_precision: 0.9324
#
# Epoch 00081: val_loss did not improve from 0.10660
# Epoch 82/100
# 21/21 [==============================] - 11s 517ms/step - loss: 0.0810 - dice: 0.9253 - iou: 0.8758 - recall: 0.8512 - precision: 0.9746 - val_loss: 0.1980 - val_dice: 0.8353 - val_iou: 0.7869 - val_recall: 0.7471 - val_precision: 0.9164
#
# Epoch 00082: val_loss did not improve from 0.10660
# Epoch 83/100
# 21/21 [==============================] - 11s 519ms/step - loss: 0.0817 - dice: 0.9246 - iou: 0.8750 - recall: 0.8480 - precision: 0.9768 - val_loss: 0.1344 - val_dice: 0.8802 - val_iou: 0.8210 - val_recall: 0.8202 - val_precision: 0.9505
#
# Epoch 00083: val_loss did not improve from 0.10660
# Epoch 84/100
# 21/21 [==============================] - 11s 515ms/step - loss: 0.0817 - dice: 0.9247 - iou: 0.8753 - recall: 0.8510 - precision: 0.9751 - val_loss: 0.1735 - val_dice: 0.8483 - val_iou: 0.7938 - val_recall: 0.7671 - val_precision: 0.9114
#
# Epoch 00084: val_loss did not improve from 0.10660
# Epoch 85/100
# 21/21 [==============================] - 11s 515ms/step - loss: 0.0828 - dice: 0.9236 - iou: 0.8724 - recall: 0.8511 - precision: 0.9740 - val_loss: 0.1620 - val_dice: 0.8612 - val_iou: 0.8085 - val_recall: 0.7948 - val_precision: 0.9292
#
# Epoch 00085: val_loss did not improve from 0.10660
# Epoch 86/100
# 21/21 [==============================] - 11s 516ms/step - loss: 0.0804 - dice: 0.9260 - iou: 0.8772 - recall: 0.8512 - precision: 0.9754 - val_loss: 0.1515 - val_dice: 0.8693 - val_iou: 0.8136 - val_recall: 0.8002 - val_precision: 0.9323
#
# Epoch 00086: val_loss did not improve from 0.10660
# Epoch 87/100
# 21/21 [==============================] - 11s 516ms/step - loss: 0.0818 - dice: 0.9245 - iou: 0.8741 - recall: 0.8510 - precision: 0.9737 - val_loss: 0.1560 - val_dice: 0.8663 - val_iou: 0.8214 - val_recall: 0.8036 - val_precision: 0.9324
#
# Epoch 00087: val_loss did not improve from 0.10660
#
# Epoch 00087: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# Saved model and weights in the directory
# Loaded best weights:  /content/drive/MyDrive/CVDL/dataset/results/models/dbunet_BN_vgg16_Glorot_e100_lr0.001/Model.hdf5

# %%
results_tf = model.evaluate(dataset_list[0]['test'], dataset_list[1]['test'], return_dict = True)
# Out:
# 2/2 [==============================] - 1s 190ms/step - loss: 0.1401 - dice: 0.8497 - iou: 0.7592 - recall: 0.8598 - precision: 0.8821

# %%
threshold = 0.5
min_dice = 0.60
results_df, avg = plots.get_results(dataset_list, params, model, threshold)
print(results_df)
print('\n')
print(f"Threshold value: {threshold}")
print(f"Best dice: {max(results_df['dice'])}")
print(f"Average dice: {results_df['dice'].describe()}")
print(f"Minimum requested dice value (bad samples): {min_dice}")
good_res = results_df.loc[(results_df['dice'] >= min_dice)]
print(f"Average dice without bad samples: {good_res['dice'].mean()}")
# Out:
#         dice
# 0   0.750341
# 1   0.924043
# 2   0.928261
# 3   0.942247
# 4   0.904741
# 5   0.903257
# 6   0.874023
# 7   0.910211
# 8   0.882306
# 9   0.923648
# 10  0.906593
# 11  0.922085
# 12  0.911445
# 13  0.883185
# 14  0.930208
# 15  0.914842
# 16  0.914926
# 17  0.934029
# 18  0.874965
# 19  0.849300
# 20  0.932846
# 21  0.856924
# 22  0.933794
# 23  0.954254
# 24  0.940682
# 25  0.918433
# 26  0.926671
# 27  0.912688
# 28  0.885116
# 29  0.907478
# 30  0.896386
# 31  0.952279
# 32  0.812125
# 33  0.762483
# 34  0.374023
# 35  0.874400
# 36  0.901744
# 37  0.836520
# 38  0.901902
# 39  0.823805
# 40  0.940293
# 41  0.924347
# 42  0.826307
# 43  0.515882
#
#
# Threshold value: 0.5
# Best dice: 0.9542543458371455
# Average dice: count    44.000000
# mean      0.874910
# std       0.106540
# min       0.374023
# 25%       0.874306
# 50%       0.907036
# 75%       0.924928
# max       0.954254
# Name: dice, dtype: float64
# Minimum requested dice value (bad samples): 0.6
# Average dice without bad samples: 0.8953841639273431

# %%
#name = f'{arch_name}_drop0.2_vl.15395_test.2173/'
lr = params['learningRate']

name = f'{arch_name}_lr{lr}_prenderequesto/'
model.save(f'/content/drive/MyDrive/CVDL/trained_models/{name}/model.hdf5')
lib.create_dump(train_history, f'/content/drive/MyDrive/CVDL/trained_models/{name}/train_history')
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)

# %%
restults_df = lib.evaluate(dataset_list, model, params)
bad_pred = lib.get_bad_pred(restults_df)
plots.plot_bad_predictions(bad_pred, dataset_list, params, model)
# Out:
#         dice
# 0   0.750341
# 1   0.924043
# 2   0.928261
# 3   0.942247
# 4   0.904741
# 5   0.903257
# 6   0.874023
# 7   0.910211
# 8   0.882306
# 9   0.923648
# 10  0.906593
# 11  0.922085
# 12  0.911445
# 13  0.883185
# 14  0.930208
# 15  0.914842
# 16  0.914926
# 17  0.934029
# 18  0.874965
# 19  0.849300
# 20  0.932846
# 21  0.856924
# 22  0.933794
# 23  0.954254
# 24  0.940682
# 25  0.918433
# 26  0.926671
# 27  0.912688
# 28  0.885116
# 29  0.907478
# 30  0.896386
# 31  0.952279
# 32  0.812125
# 33  0.762483
# 34  0.374023
# 35  0.874400
# 36  0.901744
# 37  0.836520
# 38  0.901902
# 39  0.823805
# 40  0.940293
# 41  0.924347
# 42  0.826307
# 43  0.515882
# Average dice: 0.8953841639273431
#         dice
# 34  0.374023
# 43  0.515882
# Ratio: 0.045454545454545456
#
#
#
#
# Image index 34 - dice: dice    0.374023
# Name: 34, dtype: float64
# Image index 43 - dice: dice    0.515882
# Name: 43, dtype: float64

# %% [markdown]
# # Evaluate

# %% [markdown]
# ### Unet

# %%
restults_df = lib.evaluate(dataset_list, model_unet, params)
bad_pred = lib.get_bad_pred(restults_df)
plots.plot_bad_predictions(bad_pred, dataset_list, params, model_unet)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-e16a876ca69f> in <module>()
# ----> 1 restults_df = lib.evaluate(dataset_list, model_unet, params)
#       2 bad_pred = lib.get_bad_pred(restults_df)
#       3 plots.plot_bad_predictions(bad_pred, dataset_list, params, model_unet)
#
# NameError: name 'model_unet' is not defined

# %% [markdown]
# ### Lightweight Unet

# %%
restults_df = lib.evaluate(dataset_list, model_lunet, params)
bad_pred = lib.get_bad_pred(restults_df)
plots.plot_bad_predictions(bad_pred, dataset_list, params, model_lunet)
# Out:
#         dice
# 0   0.695327
# 1   0.776329
# 2   0.908989
# 3   0.897252
# 4   0.918621
# 5   0.903818
# 6   0.878073
# 7   0.824700
# 8   0.914986
# 9   0.934274
# 10  0.663591
# 11  0.804945
# 12  0.918446
# 13  0.640575
# 14  0.931378
# 15  0.913124
# 16  0.938776
# 17  0.704264
# 18  0.888889
# 19  0.664425
# 20  0.900249
# 21  0.873501
# 22  0.913844
# 23  0.925234
# 24  0.846507
# 25  0.918433
# 26  0.922061
# 27  0.903014
# 28  0.613169
# 29  0.925114
# 30  0.836619
# 31  0.935009
# 32  0.655621
# 33  0.933845
# 34  0.832255
# 35  0.718497
# 36  0.769124
# 37  0.777939
# 38  0.886937
# 39  0.753853
# 40  0.896477
# 41  0.899679
# 42  0.814414
# 43  0.827518
# Average dice: 0.8409021114968097
# Empty DataFrame
# Columns: [dice]
# Index: []
# Ratio: 0.0

# %% [markdown]
# ### Double LUnet

# %%
restults_df = lib.evaluate(dataset_list, model_dblunet, params)
bad_pred = lib.get_bad_pred(restults_df)
plots.plot_bad_predictions(bad_pred, dataset_list, params, model_dblunet)
# Out:
#         dice
# 0   0.860024
# 1   0.925186
# 2   0.930312
# 3   0.913642
# 4   0.945693
# 5   0.945473
# 6   0.913196
# 7   0.908168
# 8   0.938356
# 9   0.937937
# 10  0.937313
# 11  0.904893
# 12  0.926339
# 13  0.908891
# 14  0.950678
# 15  0.935342
# 16  0.928763
# 17  0.941118
# 18  0.879325
# 19  0.814163
# 20  0.898998
# 21  0.924149
# 22  0.944255
# 23  0.959441
# 24  0.932267
# 25  0.936741
# 26  0.928105
# 27  0.923182
# 28  0.907796
# 29  0.932954
# 30  0.812667
# 31  0.956646
# 32  0.705882
# 33  0.943216
# 34  0.880884
# 35  0.947687
# 36  0.926745
# 37  0.893691
# 38  0.904203
# 39  0.825234
# 40  0.905782
# 41  0.906819
# 42  0.799389
# 43  0.677693
# Average dice: 0.9027099356017142
# Empty DataFrame
# Columns: [dice]
# Index: []
# Ratio: 0.0

# %% [markdown]
# # Plots

# %% [markdown]
# ### Unet

# %%
# Unet
plots.plot_train_metric(history_unet, params['nEpoches'], "dice")
plt.show()

# %% [markdown]
# ### Lightweight Unet

# %%
# LUnet
plots.plot_train_metric(history_lunet, params['nEpoches'], "dice")
plt.show()

# %% [markdown]
# ### Double LUnet

# %%
# DBLUnet
plots.plot_train_metric(history_dblunet, params['nEpoches'], "dice")
plt.show()
